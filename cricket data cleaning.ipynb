# %% [markdown]
# # Data cleaning - ESPN
#
# **The data consist of Highest test cricket career average from https://www.espncricinfo.com/records/highest-career-batting-average-282910
# My objecctive is to show you how to clean up data within Python Pandas within Jupyter notebook**

# %%
import pandas as pd

df = pd.read_csv("C:/Users/admin/Documents/Crickettestmatchdata.csv")

# %%
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1      HC Brook (ENG)  2022-2023   12    20   1  1181   186  62.15   1287
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 63   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 64  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 65  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 66    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 67   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s
# 0   58.60   29  13   7   626   6
# ...

# %%
# to view all the columns and rows

pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)
df
# Out:
#                       Player       Span  Mat  Inns  NO   Runs    HS    Ave  \
# 0           DG Bradman (AUS)  1928-1948   52    80  10   6996   334  99.94
# 1             HC Brook (ENG)  2022-2023   12    20   1   1181   186  62.15
# 2             AC Voges (AUS)  2015-2016   20    31   7   1485  269*  61.87
# 3            RG Pollock (SA)  1963-1970   23    41   4   2256   274  60.97
# 4            GA Headley (WI)  1930-1954   22    40   4   2190  270*  60.83
# 5            GA Headley (WI)  1930-1954   22    40   4   2190  270*  60.83
# 6          H Sutcliffe (ENG)  1924-1935   54    84   9   4555   194  60.73
# 7            E Paynter (ENG)  1931-1939   20    31   5   1540   243  59.23
# 8        KF Barrington (ENG)  1955-1968   82   131  15   6806   256  58.67
# 9             ED Weekes (WI)  1948-1958   48    81   5   4455   207  58.61
# 10          WR Hammond (ENG)  1927-1947   85   140  16   7249  336*  58.45
# ...

# %%
# rename multiple columns in a list

df = df.rename(columns = {"NO":"Not_out", "HS":"Highest_innings","BF":"Balls_faced","Mat":"Matches","SR":"Batting_strikerate"})

# %%
df
# Out:
#                       Player       Span  Matches  Inns  Not_out   Runs  \
# 0           DG Bradman (AUS)  1928-1948       52    80       10   6996
# 1             HC Brook (ENG)  2022-2023       12    20        1   1181
# 2             AC Voges (AUS)  2015-2016       20    31        7   1485
# 3            RG Pollock (SA)  1963-1970       23    41        4   2256
# 4            GA Headley (WI)  1930-1954       22    40        4   2190
# 5            GA Headley (WI)  1930-1954       22    40        4   2190
# 6          H Sutcliffe (ENG)  1924-1935       54    84        9   4555
# 7            E Paynter (ENG)  1931-1939       20    31        5   1540
# 8        KF Barrington (ENG)  1955-1968       82   131       15   6806
# 9             ED Weekes (WI)  1948-1958       48    81        5   4455
# 10          WR Hammond (ENG)  1927-1947       85   140       16   7249
# 11           SPD Smith (AUS)  2010-2023      103   183       22   9396
# ...

# %%
#Check null values

df.isnull().any()
# Out:
# Player                False
# Span                  False
# Matches               False
# Inns                  False
# Not_out               False
# Runs                  False
# Highest_innings       False
# Ave                   False
# Balls_faced           False
# Batting_strikerate    False
# 100                   False
# 50                    False
# 0                     False
# 4s                    False
# 6s                    False
# dtype: bool

# %%
#drop a column

columns_to_drop = ['column_name']  # replace with the names of the columns you want to drop

# Drop columns with specified names
df = df.drop(columns=columns_to_drop, axis=1) #axis 0 for row
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[287], line 6
#       3 columns_to_drop = ['column_name']  # replace with the names of the columns you want to drop
#       5 # Drop columns with specified names
# ----> 6 df = df.drop(columns=columns_to_drop, axis=1)
#       7 df
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
#making blank in a specific column

import pandas as pd

# Assuming 'df' is your DataFrame, 'column_name' is the name of the column, and 'row_index' is the index of the row
   #optional to multi remove
#row_index =   # replace with the index of the row you want to modify

# Set the value in the specified row and column to an empty string
df.at[18, 'Balls_faced'] = 0
df

# %%
df[df['Balls_faced'].isna()==1] #this will give the output of entire rows where its null
# Out:
# Empty DataFrame
# Columns: [Player, Matches, Inns, Not_out, Runs, Highest_innings, Ave, Balls_faced, Batting_strikerate, 100, 50, 0, 4s, 6s, First_year, Final_year, Team]
# Index: []

# %%
#filling a blank column with a value
#below there is another method to change it as whole
#Convert to integer, handle NaN values by replacing them with a default value (e.g., 0)
#df['Balls_faced'] = df['Balls_faced'].fillna(0).astype(int)
#df  
df['Balls_faced'] = df['Balls_faced'].fillna(0)
df
# Out:
#                       Player       Span  Matches  Inns  Not_out   Runs  \
# 0           DG Bradman (AUS)  1928-1948       52    80       10   6996
# 1             HC Brook (ENG)  2022-2023       12    20        1   1181
# 2             AC Voges (AUS)  2015-2016       20    31        7   1485
# 3            RG Pollock (SA)  1963-1970       23    41        4   2256
# 4            GA Headley (WI)  1930-1954       22    40        4   2190
# 5            GA Headley (WI)  1930-1954       22    40        4   2190
# 6          H Sutcliffe (ENG)  1924-1935       54    84        9   4555
# 7            E Paynter (ENG)  1931-1939       20    31        5   1540
# 8        KF Barrington (ENG)  1955-1968       82   131       15   6806
# 9             ED Weekes (WI)  1948-1958       48    81        5   4455
# 10          WR Hammond (ENG)  1927-1947       85   140       16   7249
# 11           SPD Smith (AUS)  2010-2023      103   183       22   9396
# ...

# %%
df.loc[9:9] # to view a specific row we use loc and iloc function
# Out:
#            Player       Span  Matches  Inns  Not_out  Runs Highest_innings  \
# 9  ED Weekes (WI)  1948-1958       48    81        5  4455             207
#
#      Ave Balls_faced Batting_strikerate  100  50  0   4s  6s
# 9  58.61           -                  -   15  19  6  258   2

# %%
df[df['Player'] == 'ED Weekes (WI)'] #we can view like this too
# Out:
#            Player       Span  Matches  Inns  Not_out  Runs Highest_innings  \
# 9  ED Weekes (WI)  1948-1958       48    81        5  4455             207
#
#      Ave Balls_faced Batting_strikerate  100  50  0   4s  6s
# 9  58.61           -                  -   15  19  6  258   2

# %%
#drop dupplicated
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5      True
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13     True
# 14    False
# 15    False
# 16    False
# 17     True
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# 52    False
# 53    False
# 54     True
# 55    False
# 56    False
# 57    False
# 58    False
# 59    False
# 60    False
# 61    False
# 62    False
# 63    False
# 64    False
# 65    False
# 66    False
# 67    False
# dtype: bool

# %%
df[df.duplicated]
# Out:
#              Player       Span  Matches  Inns  Not_out  Runs Highest_innings  \
# 5   GA Headley (WI)  1930-1954       22    40        4  2190            270*
# 13   GS Sobers (WI)  1954-1974       93   160       21  8032            365*
# 17   JB Hobbs (ENG)  1908-1930       61   102        7  5410             211
# 54    V Kohli (IND)  2011-2023      111   187       11  8676            254*
#
#       Ave Balls_faced Batting_strikerate  100  50   0   4s  6s
# 5   60.83        416+              56.00   10   5   2  104   1
# 13  57.78       4063+              53.58   26  30  12  593  32
# 17  56.94       5363+              46.22   15  28   4  276   8
# 54  49.29       15708              55.23   29  29  14  966  24

# %%
# The isin method in pandas is used to filter data based on a list of values
df[df['Player'].isin(['GS Sobers (WI)', 'V Kohli (IND)', 'GA Headley (WI)','JB Hobbs (ENG)'])]
# Out:
#              Player       Span  Matches  Inns  Not_out  Runs Highest_innings  \
# 4   GA Headley (WI)  1930-1954       22    40        4  2190            270*
# 5   GA Headley (WI)  1930-1954       22    40        4  2190            270*
# 12   GS Sobers (WI)  1954-1974       93   160       21  8032            365*
# 13   GS Sobers (WI)  1954-1974       93   160       21  8032            365*
# 16   JB Hobbs (ENG)  1908-1930       61   102        7  5410             211
# 17   JB Hobbs (ENG)  1908-1930       61   102        7  5410             211
# 53    V Kohli (IND)  2011-2023      111   187       11  8676            254*
# 54    V Kohli (IND)  2011-2023      111   187       11  8676            254*
#
#       Ave Balls_faced Batting_strikerate  100  50   0   4s  6s
# 4   60.83        416+              56.00   10   5   2  104   1
# 5   60.83        416+              56.00   10   5   2  104   1
# 12  57.78       4063+              53.58   26  30  12  593  32
# ...

# %%
#df = df.drop_duplicates() 

#or

# Drop duplicate rows in place
df.drop_duplicates(inplace=True)
df[df['Player'].isin(['GS Sobers (WI)', 'V Kohli (IND)', 'GA Headley (WI)','JB Hobbs (ENG)'])]
#This will modify the original DataFrame (df) without the need to assign it back.

#Adjust the code based on your specific DataFrame and the columns you want to consider for detecting duplicates.
# Out:
#              Player       Span  Matches  Inns  Not_out  Runs Highest_innings  \
# 4   GA Headley (WI)  1930-1954       22    40        4  2190            270*
# 12   GS Sobers (WI)  1954-1974       93   160       21  8032            365*
# 16   JB Hobbs (ENG)  1908-1930       61   102        7  5410             211
# 53    V Kohli (IND)  2011-2023      111   187       11  8676            254*
#
#       Ave Balls_faced Batting_strikerate  100  50   0   4s  6s
# 4   60.83        416+              56.00   10   5   2  104   1
# 12  57.78       4063+              53.58   26  30  12  593  32
# 16  56.94       5363+              46.22   15  28   4  276   8
# 53  49.29       15708              55.23   29  29  14  966  24

# %%
df.at[59, 'Balls_faced'] = 0
df
# Out:
#                       Player       Span  Matches  Inns  Not_out   Runs  \
# 0           DG Bradman (AUS)  1928-1948       52    80       10   6996
# 1             HC Brook (ENG)  2022-2023       12    20        1   1181
# 2             AC Voges (AUS)  2015-2016       20    31        7   1485
# 3            RG Pollock (SA)  1963-1970       23    41        4   2256
# 4            GA Headley (WI)  1930-1954       22    40        4   2190
# 6          H Sutcliffe (ENG)  1924-1935       54    84        9   4555
# 7            E Paynter (ENG)  1931-1939       20    31        5   1540
# 8        KF Barrington (ENG)  1955-1968       82   131       15   6806
# 9             ED Weekes (WI)  1948-1958       48    81        5   4455
# 10          WR Hammond (ENG)  1927-1947       85   140       16   7249
# 11           SPD Smith (AUS)  2010-2023      103   183       22   9396
# 12            GS Sobers (WI)  1954-1974       93   160       21   8032
# ...

# %% [markdown]
# To split a column in a pandas DataFrame into multiple columns, you can use the str.split method along with the expand parameter. This is useful when you have a column containing delimited or structured data, and you want to separate it into different columns.
#
# Here's an example:
#
# python
# Copy code
# import pandas as pd
#
# #### Assuming 'df' is your DataFrame
# data = {'Full_Name': ['John Doe', 'Jane Smith', 'Alice Johnson']}
# df = pd.DataFrame(data)
#
# #### Split the 'Full_Name' column into 'First_Name' and 'Last_Name'
# df[['First_Name', 'Last_Name']] = df['Full_Name'].str.split(expand=True)
#
# #### Display the DataFrame after splitting
# print(df)
# This will produce a DataFrame with the 'Full_Name' column split into two separate columns, 'First_Name' and 'Last_Name':
#
# plaintext
# Copy code
#        Full_Name First_Name Last_Name
# 0      John Doe       John       Doe
# 1   Jane Smith       Jane     Smith
# 2  Alice Johnson     Alice   Johnson
# In this example, str.split(expand=True) splits the 'Full_Name' column at whitespace, and the expand=True parameter ensures that the result is expanded into separate columns.
#
# If your data is delimited by a specific character (e.g., a comma or underscore), you can specify the delimiter within the str.split method:
#
# python
# Copy code
# #### Assuming 'df' is your DataFrame
# data = {'Full_Name': ['John_Doe', 'Jane_Smith', 'Alice_Johnson']}
# df = pd.DataFrame(data)
#
# #### Split the 'Full_Name' column using underscores
# df[['First_Name', 'Last_Name']] = df['Full_Name'].str.split('_', expand=True)
#
# #### Display the DataFrame after splitting
# print(df)
# This will split the 'Full_Name' column using underscores as the delimiter.
#
# Adjust the code based on the structure of your data and the delimiter you want to use for splitting.

# %%
# split up span into start and end date 
df.dtypes

df['Span']
# Out:
#   Cell In[296], line 4
#     df['Span'].
#                ^
# SyntaxError: invalid syntax

# %%
df['Span'].str.split(pat = '-')
# Out:
# 0     [1928, 1948]
# 1     [2022, 2023]
# 2     [2015, 2016]
# 3     [1963, 1970]
# 4     [1930, 1954]
# 6     [1924, 1935]
# 7     [1931, 1939]
# 8     [1955, 1968]
# 9     [1948, 1958]
# 10    [1927, 1947]
# 11    [2010, 2023]
# 12    [1954, 1974]
# 14    [2000, 2015]
# 15    [1908, 1930]
# 16    [1908, 1930]
# 18    [1948, 1960]
# 19    [1937, 1955]
# 20    [1995, 2013]
# 21    [1921, 1929]
# 22    [2010, 2023]
# 23    [1968, 1973]
# 24    [1993, 1995]
# 25    [1970, 1984]
# 26    [1935, 1951]
# 27    [1989, 2013]
# 28    [2019, 2023]
# 29    [1990, 2006]
# 30    [1976, 1993]
# 31    [1996, 2012]
# 32    [1998, 2010]
# 33    [2018, 2023]
# 34    [2000, 2017]
# 35    [1995, 2012]
# 36    [1920, 1929]
# 37    [1992, 2002]
# 38    [2005, 2013]
# 39    [1994, 2015]
# 40    [1971, 1987]
# 41    [1985, 2004]
# 42    [1994, 2009]
# 43    [2004, 2018]
# 44    [1978, 1994]
# 45    [2012, 2023]
# 46    [1974, 1991]
# 47    [1937, 1957]
# 48    [1997, 2014]
# 49    [1992, 2007]
# ...

# %%
#df['Final_year'] = df['Span'].str.split(pat = '-')
#df['First_year'] = df['Span'].str.split(pat = '-')

#or

df[['First_year', 'Final_year']] = df['Span'].str.split('-', expand=True)
df
# Out:
#                       Player       Span  Matches  Inns  Not_out   Runs  \
# 0           DG Bradman (AUS)  1928-1948       52    80       10   6996
# 1             HC Brook (ENG)  2022-2023       12    20        1   1181
# 2             AC Voges (AUS)  2015-2016       20    31        7   1485
# 3            RG Pollock (SA)  1963-1970       23    41        4   2256
# 4            GA Headley (WI)  1930-1954       22    40        4   2190
# 6          H Sutcliffe (ENG)  1924-1935       54    84        9   4555
# 7            E Paynter (ENG)  1931-1939       20    31        5   1540
# 8        KF Barrington (ENG)  1955-1968       82   131       15   6806
# 9             ED Weekes (WI)  1948-1958       48    81        5   4455
# 10          WR Hammond (ENG)  1927-1947       85   140       16   7249
# 11           SPD Smith (AUS)  2010-2023      103   183       22   9396
# 12            GS Sobers (WI)  1954-1974       93   160       21   8032
# ...

# %%
df.drop(['Span'], axis = 1, inplace = True)
df
# Out:
#                       Player  Matches  Inns  Not_out   Runs Highest_innings  \
# 0           DG Bradman (AUS)       52    80       10   6996             334
# 1             HC Brook (ENG)       12    20        1   1181             186
# 2             AC Voges (AUS)       20    31        7   1485            269*
# 3            RG Pollock (SA)       23    41        4   2256             274
# 4            GA Headley (WI)       22    40        4   2190            270*
# 6          H Sutcliffe (ENG)       54    84        9   4555             194
# 7            E Paynter (ENG)       20    31        5   1540             243
# 8        KF Barrington (ENG)       82   131       15   6806             256
# 9             ED Weekes (WI)       48    81        5   4455             207
# 10          WR Hammond (ENG)       85   140       16   7249            336*
# 11           SPD Smith (AUS)      103   183       22   9396             239
# ...

# %%
#split up the country from the player

df[['Player', 'Team']] = df['Player'].str.split('(', expand=True)
df
# Out:
#                 Player  Matches  Inns  Not_out   Runs Highest_innings    Ave  \
# 0          DG Bradman        52    80       10   6996             334  99.94
# 1            HC Brook        12    20        1   1181             186  62.15
# 2            AC Voges        20    31        7   1485            269*  61.87
# 3          RG Pollock        23    41        4   2256             274  60.97
# 4          GA Headley        22    40        4   2190            270*  60.83
# 6         H Sutcliffe        54    84        9   4555             194  60.73
# 7           E Paynter        20    31        5   1540             243  59.23
# 8       KF Barrington        82   131       15   6806             256  58.67
# 9           ED Weekes        48    81        5   4455             207  58.61
# 10         WR Hammond        85   140       16   7249            336*  58.45
# 11          SPD Smith       103   183       22   9396             239  58.36
# ...

# %%
 #Remove ')' from the 'Team' column
df['Team'] = df['Team'].str.replace(r'\)', '')

# Display the modified DataFrame
df

#In the str.replace(r'\)', '') expression, r'\)' is a regular expression pattern that matches the ')' character. The str.replace method replaces all occurrences of ')' with an empty string.
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_13944\2712957675.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Team'] = df['Team'].str.replace(r'\)', '')
#                 Player  Matches  Inns  Not_out   Runs Highest_innings    Ave  \
# 0          DG Bradman        52    80       10   6996             334  99.94
# 1            HC Brook        12    20        1   1181             186  62.15
# 2            AC Voges        20    31        7   1485            269*  61.87
# 3          RG Pollock        23    41        4   2256             274  60.97
# 4          GA Headley        22    40        4   2190            270*  60.83
# 6         H Sutcliffe        54    84        9   4555             194  60.73
# 7           E Paynter        20    31        5   1540             243  59.23
# 8       KF Barrington        82   131       15   6806             256  58.67
# ...

# %% [markdown]
# df = pd.DataFrame(data)
#
# #Specify the desired column order
# desired_column_order = ['Team', 'Player', 'Span', 'Matches', ...]  # Add other column names as needed
#
# #Reorder columns in the DataFrame
# df = df[desired_column_order]
#
#  #Display the modified DataFrame
# print(df)
#
# In this example, desired_column_order is a list that contains the column names in the desired order. By reassigning the DataFrame using df[desired_column_order], you rearrange the columns according to the specified order.
#
# Make sure to replace ... with the actual list of other column names. Adjust the code based on your specific DataFrame and the order you want for your columns

# %%
# change datatype

df.dtypes
# Out:
# Player                 object
# Matches                 int64
# Inns                    int64
# Not_out                 int64
# Runs                    int64
# Highest_innings        object
# Ave                   float64
# Balls_faced            object
# Batting_strikerate     object
# 100                     int64
# 50                      int64
# 0                       int64
# 4s                      int64
# 6s                      int64
# First_year             object
# Final_year             object
# Team                   object
# dtype: object

# %%
df['Highest_innings'] = df['Highest_innings'].str.split(pat = '*').str[0]

# %%
df
# Out:
#                 Player  Matches  Inns  Not_out   Runs Highest_innings    Ave  \
# 0          DG Bradman        52    80       10   6996             334  99.94
# 1            HC Brook        12    20        1   1181             186  62.15
# 2            AC Voges        20    31        7   1485             269  61.87
# 3          RG Pollock        23    41        4   2256             274  60.97
# 4          GA Headley        22    40        4   2190             270  60.83
# 6         H Sutcliffe        54    84        9   4555             194  60.73
# 7           E Paynter        20    31        5   1540             243  59.23
# 8       KF Barrington        82   131       15   6806             256  58.67
# 9           ED Weekes        48    81        5   4455             207  58.61
# 10         WR Hammond        85   140       16   7249             336  58.45
# 11          SPD Smith       103   183       22   9396             239  58.36
# ...

# %%
df['Highest_innings'] = df['Highest_innings'].astype('int')

# %%
df.dtypes
# Out:
# Player                 object
# Matches                 int64
# Inns                    int64
# Not_out                 int64
# Runs                    int64
# Highest_innings         int32
# Ave                   float64
# Balls_faced            object
# Batting_strikerate     object
# 100                     int64
# 50                      int64
# 0                       int64
# 4s                      int64
# 6s                      int64
# First_year             object
# Final_year             object
# Team                   object
# dtype: object

# %%
#see if you can fix first year and final year

df = df.astype({'First_year' : 'int','Final_year' : 'int'})

# %%
df = df.astype({'Batting_strikerate' : 'float'})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[320], line 1
# ----> 1 df = df.astype({'Batting_strikerate' : 'float'})
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:6226, in NDFrame.astype(self, dtype, copy, errors)
#    6224             res_col = col.copy() if copy else col
#    6225         else:
# -> 6226             res_col = col.astype(dtype=cdt, copy=copy, errors=errors)
#    6227         results.append(res_col)
#    6229 elif is_extension_array_dtype(dtype) and self.ndim > 1:
#    6230     # GH 18099/22869: columnwise conversion to extension dtype
#    6231     # GH 24704: use iloc to handle duplicate column names
#    6232     # TODO(EA2D): special case not needed with 2D EAs
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
# ...

# %% [markdown]
# ValueError: could not convert string to float: '-'
#
#
# The error "could not convert string to float: '-'" is occurring because there is a string value '-' in your data, and you are trying to convert it to a float. In Python, the '-' string cannot be directly converted to a float.
#
# To handle this situation, you can modify your code to replace the '-' values with something else or handle them in a way that suits your analysis. Here's an example using pandas:

# %%
df['Batting_strikerate'] = df['Batting_strikerate'].replace('-',float(0.00)).astype('float')
df
# Out:
#                 Player  Matches  Inns  Not_out   Runs  Highest_innings    Ave  \
# 0          DG Bradman        52    80       10   6996              334  99.94
# 1            HC Brook        12    20        1   1181              186  62.15
# 2            AC Voges        20    31        7   1485              269  61.87
# 3          RG Pollock        23    41        4   2256              274  60.97
# 4          GA Headley        22    40        4   2190              270  60.83
# 6         H Sutcliffe        54    84        9   4555              194  60.73
# 7           E Paynter        20    31        5   1540              243  59.23
# 8       KF Barrington        82   131       15   6806              256  58.67
# 9           ED Weekes        48    81        5   4455              207  58.61
# 10         WR Hammond        85   140       16   7249              336  58.45
# 11          SPD Smith       103   183       22   9396              239  58.36
# ...

# %% [markdown]
# The fillna method in pandas is used to fill (or replace) missing (NaN) values in a DataFrame or Series with specified values. It is a convenient way to handle missing data by providing a default value or a strategy for replacing those missing values.
#
# Here are some common reasons for using fillna:
#
# Replace NaN with a Default Value:
#
# python
# Copy code
# df['column_name'].fillna(default_value, inplace=True)
# This is useful when you want to replace all NaN values in a specific column with a default value.
#
# Fill Forward or Backward:
#
# python
# Copy code
# df.fillna(method='ffill')  # forward fill
# df.fillna(method='bfill')  # backward fill
# You can fill NaN values with the last valid observation (forward fill) or the next valid observation (backward fill).
#
# Replace NaN with Mean, Median, or Mode:
#
# python
# Copy code
# mean_value = df['column_name'].mean()
# df['column_name'].fillna(mean_value, inplace=True)
# You can replace NaN values with the mean, median, or mode of the column.
#
# Replace NaN with Interpolated Values:
#
# python
# Copy code
# df['column_name'].interpolate(inplace=True)
# Interpolation is useful when you want to fill NaN values using linear or polynomial interpolation based on the surrounding values.
#
# Replace NaN in Entire DataFrame:
#
# python
# Copy code
# df.fillna(value, inplace=True)
# You can replace all NaN values in the entire DataFrame with a specified value.
#
# Using fillna helps ensure that your data is consistent and suitable for analysis or further processing. The inplace=True parameter modifies the DataFrame in place without the need for reassignment.
#
# Remember to choose a filling strategy that aligns with the nature of your data and the requirements of your analysis.

# %%
# you cannot change the datatype since it has - and + on the balls faced so first we have to change it
#remove the + on the Balls_faced
#replace - with 0

df['Balls_faced'] = df['Balls_faced'].str.split(pat = '+').str[0]
df.Balls_faced
# Convert to numeric, handle non-numeric values by converting them to NaN
#pd.to_numeric(df['Balls_faced'], errors='coerce')

#Convert to integer, handle NaN values by replacing them with a default value (e.g., 0)
df['Balls_faced'] = df['Balls_faced'].fillna(0).astype(int)
df
# Out:
#                 Player  Matches  Inns  Not_out   Runs  Highest_innings    Ave  \
# 0          DG Bradman        52    80       10   6996              334  99.94
# 1            HC Brook        12    20        1   1181              186  62.15
# 2            AC Voges        20    31        7   1485              269  61.87
# 3          RG Pollock        23    41        4   2256              274  60.97
# 4          GA Headley        22    40        4   2190              270  60.83
# 6         H Sutcliffe        54    84        9   4555              194  60.73
# 7           E Paynter        20    31        5   1540              243  59.23
# 8       KF Barrington        82   131       15   6806              256  58.67
# 9           ED Weekes        48    81        5   4455              207  58.61
# 10         WR Hammond        85   140       16   7249              336  58.45
# 11          SPD Smith       103   183       22   9396              239  58.36
# ...

# %%
df = df.astype({'Matches' : 'int'})
df
# Out:
#                 Player  Matches  Inns  Not_out   Runs  Highest_innings    Ave  \
# 0          DG Bradman        52    80       10   6996              334  99.94
# 1            HC Brook        12    20        1   1181              186  62.15
# 2            AC Voges        20    31        7   1485              269  61.87
# 3          RG Pollock        23    41        4   2256              274  60.97
# 4          GA Headley        22    40        4   2190              270  60.83
# 6         H Sutcliffe        54    84        9   4555              194  60.73
# 7           E Paynter        20    31        5   1540              243  59.23
# 8       KF Barrington        82   131       15   6806              256  58.67
# 9           ED Weekes        48    81        5   4455              207  58.61
# 10         WR Hammond        85   140       16   7249              336  58.45
# 11          SPD Smith       103   183       22   9396              239  58.36
# ...

# %%
# you should try whether you can change the stars and - nan values as a whole without changing it one by one
# Out:
# 0     99.94
# 1     62.15
# 2     61.87
# 3     60.97
# 4     60.83
# 6     60.73
# 7     59.23
# 8     58.67
# 9     58.61
# 10    58.45
# 11    58.36
# 12    57.78
# 14    57.40
# 15    56.94
# 16    56.94
# 18    56.68
# 19    56.67
# 20    55.37
# 21    55.00
# 22    54.36
# 23    54.20
# 24    54.20
# 25    53.86
# 26    53.81
# 27    53.78
# 28    53.77
# 29    52.88
# 30    52.57
# 31    52.31
# 32    52.29
# 33    52.15
# 34    52.05
# 35    51.85
# 36    51.62
# 37    51.54
# 38    51.52
# 39    51.37
# 40    51.12
# 41    51.06
# 42    50.73
# 43    50.66
# 44    50.56
# 45    50.29
# 46    50.23
# 47    50.06
# 48    49.84
# 49    49.60
# 50    49.48
# 51    49.37
# 52    49.34
# 53    49.29
# 55    49.16
# 56    49.10
# 57    49.08
# 58    48.88
# 59    48.79
# 60    48.76
# 61    48.61
# 62    48.41
# 63    48.26
# 64    48.25
# 65    48.22
# 66    48.21
# 67    48.00
# Name: Ave, dtype: float64

# %%
# remove fs jackson row

df = df.drop(56, axis = 0)

# %%
df.dtypes
# Out:
# Player                 object
# Matches                 int32
# Inns                    int64
# Not_out                 int64
# Runs                    int64
# Highest_innings         int32
# Ave                   float64
# Balls_faced             int32
# Batting_strikerate    float64
# 100                     int64
# 50                      int64
# 0                       int64
# 4s                      int64
# 6s                      int64
# First_year              int32
# Final_year              int32
# Team                   object
# dtype: object

# %%
#build a career length column - final - first

df['Career_length'] = df['Final_year'] - df['First_year']
df
# Out:
#                 Player  Matches  Inns  Not_out   Runs  Highest_innings    Ave  \
# 0          DG Bradman        52    80       10   6996              334  99.94
# 1            HC Brook        12    20        1   1181              186  62.15
# 2            AC Voges        20    31        7   1485              269  61.87
# 3          RG Pollock        23    41        4   2256              274  60.97
# 4          GA Headley        22    40        4   2190              270  60.83
# 6         H Sutcliffe        54    84        9   4555              194  60.73
# 7           E Paynter        20    31        5   1540              243  59.23
# 8       KF Barrington        82   131       15   6806              256  58.67
# 9           ED Weekes        48    81        5   4455              207  58.61
# 10         WR Hammond        85   140       16   7249              336  58.45
# 11          SPD Smith       103   183       22   9396              239  58.36
# ...

# %%
#what is the average career length of the cricketers
df['Career_length'].mean()
# Out:
# 13.095238095238095

# %%
#average strikerate for players who have plyed more then 10 years

df[df['Career_length'] > 10]['Batting_strikerate'].mean()
# Out:
# 47.73386363636364

# %%
#find number of cricketers who played before 1960

df[df['First_year']<1960]['Player'].count()
# Out:
# 24

# %%
#changing team into country

df = df.rename(columns={"Team": "Country"})

# %%
#4 highest max highest inns score by country

# Convert 'Highest_innings' to numeric (remove '*' and handle NaN values)
#df['Highest_innings'] = pd.to_numeric(df['Highest_innings'].str.replace('*', ''), errors='coerce')
#df['Balls_faced'] = df['Balls_faced'].str.split(pat = '+').str[0]
#df.Balls_faced
# Convert to numeric, handle non-numeric values by converting them to NaN
#pd.to_numeric(df['Balls_faced'], errors='coerce')

#Convert to integer, handle NaN values by replacing them with a default value (e.g., 0)
#df['Balls_faced'] = df['Balls_faced'].fillna(0).astype(int)
#df                                           

fourth_highest_scores = df.groupby('Team')['Highest_innings'].nlargest(4).groupby('Team').max()
fourth_highest_scores
# Out:
# Team
# AUS        380
# ENG        364
# ICC/IND    319
# ICC/PAK    329
# ICC/SA     277
# ICC/WI     400
# IND        254
# NZ         251
# PAK        313
# SA         278
# SL         374
# WI         365
# ZIM        232
# Name: Highest_innings, dtype: int32

# %%
df.groupby('Runs').max().sort_values('Highest_innings', ascending = False )
# Out:
#                    Player  Matches  Inns  Not_out  Highest_innings    Ave  \
# Runs
# 11953            BC Lara       131   232        6              400  52.88
# 8625           ML Hayden       103   184       14              380  50.73
# 11814   DPMD Jayawardene       149   252       15              374  49.84
# 8032           GS Sobers        93   160       21              365  57.78
# 6971            L Hutton        79   138       15              364  56.67
# 7249          WR Hammond        85   140       16              336  58.45
# 6996          DG Bradman        52    80       10              334  99.94
# 8830      Inzamam-ul-Haq       120   200       22              329  49.60
# 12400      KC Sangakkara       134   233       17              319  57.40
# 8586            V Sehwag       104   180        6              319  49.34
# 10099        Younis Khan       118   213       19              313  52.05
# 8540        IVA Richards       121   182       12              291  50.23
# ...

# %%
df.groupby('Country')['Highest_innings'].max().reset_index().sort_values('Highest_innings', ascending = False)
# Out:
#     Country  Highest_innings
# 5    ICC/WI              400
# 0       AUS              380
# 10       SL              374
# 11       WI              365
# 1       ENG              364
# 3   ICC/PAK              329
# 2   ICC/IND              319
# 8       PAK              313
# 9        SA              278
# 4    ICC/SA              277
# 6       IND              254
# 7        NZ              251
# 12      ZIM              232

# %%
#can use this way too

df.groupby('Country')['Highest_innings'].max().to_frame('Highest_innings_scoredbycountry').reset_index().sort_values('Highest_innings_scoredbycountry', ascending = False)
# Out:
#     Country  Highest_innings_scoredbycountry
# 5    ICC/WI                              400
# 0       AUS                              380
# 10       SL                              374
# 11       WI                              365
# 1       ENG                              364
# 3   ICC/PAK                              329
# 2   ICC/IND                              319
# 8       PAK                              313
# 9        SA                              278
# 4    ICC/SA                              277
# 6       IND                              254
# 7        NZ                              251
# 12      ZIM                              232

# %%
#hundreds fifties and ducks average by country

df.groupby('Country')[['100','50','0']].mean()
# Out:
#                100         50          0
# Country
# AUS      20.133333  28.066667   8.466667
# ENG      12.307692  20.769231   4.307692
# ICC/IND  29.500000  47.500000  12.000000
# ICC/PAK  25.000000  46.000000  15.000000
# ICC/SA   36.000000  48.000000  13.500000
# ICC/WI   34.000000  48.000000  17.000000
# IND      29.500000  36.250000  10.750000
# NZ       17.000000  21.000000   5.500000
# PAK      17.800000  23.200000   8.000000
# SA        9.800000  20.200000   3.400000
# SL       28.666667  44.000000  12.333333
# WI       16.444444  25.888889   6.888889
# ZIM      12.000000  27.000000   5.000000
